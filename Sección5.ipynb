# %%
#seccion5
#importando datasets

# %%
import pandas as pd

# %%
#Método 1: Especificaar Ruta Completa al archivo

# %%
#Windows
datos= pd.read_csv('C:\\Users\\danny\\OneDrive\\Escritorio\\IAgenerativaIBM\\DatosDemograficos.csv')

#Mac
#datos = pd.read_csv('/Users/Danny/Documents/DatosDemograficos.csv')

# %%
datos
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %%
#Método 2 : Cambio del working Directory

# %%
import os

# %%
print(os.getcwd()) #con esto sabemos donde esta el working directory
# Out:
# C:\Users\danny

# %%
#Windows -> la nueva ruta
#os.chdir('C:\\Users\\danny\\Desktop')

# %%
#2 Número de Filas
len(datos) #195 filas
# Out:
# 195

# %%
#3Ver las columnas
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
#4 Número de columnas
len(datos.columns)
# Out:
# 5

# %%
#5 Filas superiores
datos.head(10)
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
# 5             Argentina            ARG             17.716
# 6               Armenia            ARM             13.308
# 7   Antigua and Barbuda            ATG             16.447
# 8             Australia            AUS             13.200
# 9               Austria            AUT              9.400
#
#    Usuarios de Internet   Grupo de ingresos
# 0               78.9000        Ingreso alto
# 1                5.9000        Ingreso bajo
# 2               19.1000  Ingreso medio alto
# 3               57.2000  Ingreso medio alto
# 4               88.0000        Ingreso alto
# 5               59.9000        Ingreso alto
# ...

# %%
#6 Filas inferiores
datos.tail()
# Out:
#       Nombre del Pais Codigo de Pais  Tasa de Natalidad  Usuarios de Internet  \
# 190       Yemen, Rep.            YEM             32.947                  20.0
# 191      South Africa            ZAF             20.850                  46.5
# 192  Congo, Dem. Rep.            COD             42.394                   2.2
# 193            Zambia            ZMB             40.471                  15.4
# 194          Zimbabwe            ZWE             35.715                  18.5
#
#       Grupo de ingresos
# 190  Ingreso medio bajo
# 191  Ingreso medio alto
# 192        Ingreso bajo
# 193  Ingreso medio bajo
# 194        Ingreso bajo

# %%
#7 Informacion de las columnas
datos.info() #como la función de str de R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nombre del Pais       195 non-null    object
#  1   Codigo de Pais        195 non-null    object
#  2   Tasa de Natalidad     195 non-null    float64
#  3   Usuarios de Internet  195 non-null    float64
#  4   Grupo de ingresos     195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8 Obtener estadísticas de las columnas
datos.describe() #como sumary en R
# Out:
#        Tasa de Natalidad  Usuarios de Internet
# count         195.000000            195.000000
# mean           21.469928             42.076471
# std            10.605467             29.030788
# min             7.900000              0.900000
# 25%            12.120500             14.520000
# 50%            19.680000             41.000000
# 75%            29.759500             66.225000
# max            49.661000             96.546800

# %%
datos.describe().transpose()
# Out:
#                       count       mean        std  min      25%    50%  \
# Tasa de Natalidad     195.0  21.469928  10.605467  7.9  12.1205  19.68
# Usuarios de Internet  195.0  42.076471  29.030788  0.9  14.5200  41.00
#
#                           75%      max
# Tasa de Natalidad     29.7595  49.6610
# Usuarios de Internet  66.2250  96.5468

# %%
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
datos.columns = ['a','b','c','d','e']

# %%
datos.head()
# Out:
#                       a    b       c     d                   e
# 0                 Aruba  ABW  10.244  78.9        Ingreso alto
# 1           Afghanistan  AFG  35.253   5.9        Ingreso bajo
# 2                Angola  AGO  45.985  19.1  Ingreso medio alto
# 3               Albania  ALB  12.877  57.2  Ingreso medio alto
# 4  United Arab Emirates  ARE  11.044  88.0        Ingreso alto

# %%
datos.columns = ['NombrePais','CodigoPais','TasaNatalalidad','UsuariosInternet','GrupoIngreso']

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#tres partes
#-Filas
#-columnas
# -Combinación

# %%
#Parte1: Filas

# %%
datos[21:26]
# Out:
#    NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 21     Belize        BLZ           23.092             33.60
# 22    Bermuda        BMU           10.400             95.30
# 23    Bolivia        BOL           24.236             36.94
# 24     Brazil        BRA           14.931             51.04
# 25   Barbados        BRB           12.188             73.00
#
#           GrupoIngreso
# 21  Ingreso medio alto
# 22        Ingreso alto
# 23  Ingreso medio bajo
# 24  Ingreso medio alto
# 25        Ingreso alto

# %%
datos[100:111 ]
# Out:
#            NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 100             Libya        LBY           21.425           16.5000
# 101         St. Lucia        LCA           15.430           46.2000
# 102     Liechtenstein        LIE            9.200           93.8000
# 103         Sri Lanka        LKA           17.863           21.9000
# 104           Lesotho        LSO           28.738            5.0000
# 105         Lithuania        LTU           10.100           68.4529
# 106        Luxembourg        LUX           11.300           93.7765
# 107            Latvia        LVA           10.200           75.2344
# 108  Macao SAR, China        MAC           11.256           65.8000
# 109           Morocco        MAR           21.023           56.0000
# 110           Moldova        MDA           12.141           45.0000
#
#            GrupoIngreso
# 100  Ingreso medio alto
# 101  Ingreso medio alto
# 102        Ingreso alto
# 103  Ingreso medio bajo
# ...

# %%
datos[:10] #datos.head(10)
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244           78.9000
# 1           Afghanistan        AFG           35.253            5.9000
# 2                Angola        AGO           45.985           19.1000
# 3               Albania        ALB           12.877           57.2000
# 4  United Arab Emirates        ARE           11.044           88.0000
# 5             Argentina        ARG           17.716           59.9000
# 6               Armenia        ARM           13.308           41.9000
# 7   Antigua and Barbuda        ATG           16.447           63.4000
# 8             Australia        AUS           13.200           83.0000
# 9               Austria        AUT            9.400           80.6188
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto
# 5        Ingreso alto
# 6  Ingreso medio bajo
# ...

# %%
#ejercicio rápido
#invierte el dataFrame
datos[ : : -1]
# Out:
#                NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 194              Zimbabwe        ZWE           35.715              18.5
# 193                Zambia        ZMB           40.471              15.4
# 192      Congo, Dem. Rep.        COD           42.394               2.2
# 191          South Africa        ZAF           20.850              46.5
# 190           Yemen, Rep.        YEM           32.947              20.0
# ..                    ...        ...              ...               ...
# 4    United Arab Emirates        ARE           11.044              88.0
# 3                 Albania        ALB           12.877              57.2
# 2                  Angola        AGO           45.985              19.1
# 1             Afghanistan        AFG           35.253               5.9
# 0                   Aruba        ABW           10.244              78.9
#
#            GrupoIngreso
# 194        Ingreso bajo
# 193  Ingreso medio bajo
# 192        Ingreso bajo
# ...

# %%
datos
# Out:
#                NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                   Aruba        ABW           10.244              78.9
# 1             Afghanistan        AFG           35.253               5.9
# 2                  Angola        AGO           45.985              19.1
# 3                 Albania        ALB           12.877              57.2
# 4    United Arab Emirates        ARE           11.044              88.0
# ..                    ...        ...              ...               ...
# 190           Yemen, Rep.        YEM           32.947              20.0
# 191          South Africa        ZAF           20.850              46.5
# 192      Congo, Dem. Rep.        COD           42.394               2.2
# 193                Zambia        ZMB           40.471              15.4
# 194              Zimbabwe        ZWE           35.715              18.5
#
#            GrupoIngreso
# 0          Ingreso alto
# 1          Ingreso bajo
# 2    Ingreso medio alto
# ...

# %%
#Ejercicio rpido
#Obtener solamente cada 20 paises o filas

# %%
datos[::20]
# Out:
#      NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0         Aruba        ABW           10.244           78.9000
# 20      Belarus        BLR           12.500           54.1700
# 40   Costa Rica        CRI           15.022           45.9600
# 60        Gabon        GAB           30.555            9.2000
# 80        India        IND           20.291           15.1000
# 100       Libya        LBY           21.425           16.5000
# 120  Mozambique        MOZ           39.705            5.4000
# 140      Poland        POL            9.600           62.8492
# 160    Suriname        SUR           18.455           37.4000
# 180     Uruguay        URY           14.374           57.6900
#
#            GrupoIngreso
# 0          Ingreso alto
# 20   Ingreso medio alto
# 40   Ingreso medio alto
# 60   Ingreso medio alto
# 80   Ingreso medio bajo
# 100  Ingreso medio alto
# 120        Ingreso bajo
# 140        Ingreso alto
# 160  Ingreso medio alto
# 180        Ingreso alto

# %%
datos.columns
# Out:
# Index(['NombrePais', 'CodigoPais', 'TasaNatalalidad', 'UsuariosInternet',
#        'GrupoIngreso'],
#       dtype='object')

# %%
datos['NombrePais']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: NombrePais, Length: 195, dtype: object

# %%
datos['NombrePais'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: NombrePais, dtype: object

# %%
datos[['NombrePais','TasaNatalalidad']].head()
# Out:
#              NombrePais  TasaNatalalidad
# 0                 Aruba           10.244
# 1           Afghanistan           35.253
# 2                Angola           45.985
# 3               Albania           12.877
# 4  United Arab Emirates           11.044

# %%
#Acceso rápido
datos.TasaNatalalidad.head() #nombre de columna en una sola palabra
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: TasaNatalalidad, dtype: float64

# %%
#Parte 3 Combinar los dos métodos

# %%
df2=datos[4:8][['NombrePais','TasaNatalalidad']]

# %%
df2
# Out:
#              NombrePais  TasaNatalalidad
# 4  United Arab Emirates           11.044
# 5             Argentina           17.716
# 6               Armenia           13.308
# 7   Antigua and Barbuda           16.447

# %%
df3= datos[4:8]

# %%
df3[['NombrePais','TasaNatalalidad']]
# Out:
#              NombrePais  TasaNatalalidad
# 4  United Arab Emirates           11.044
# 5             Argentina           17.716
# 6               Armenia           13.308
# 7   Antigua and Barbuda           16.447

# %%
####Operaciones basica con un DataFrame

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
datos[['NombrePais','TasaNatalalidad','UsuariosInternet']][4:8]
# Out:
#              NombrePais  TasaNatalalidad  UsuariosInternet
# 4  United Arab Emirates           11.044              88.0
# 5             Argentina           17.716              59.9
# 6               Armenia           13.308              41.9
# 7   Antigua and Barbuda           16.447              63.4

# %%
#operaciones mátematicas
resultado = datos.TasaNatalalidad * datos.UsuariosInternet

# %%
resultado.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
#Agregar Columna:

# %%
datos['MiCalculo']=datos.TasaNatalalidad * datos.UsuariosInternet

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso  MiCalculo
# 0        Ingreso alto   808.2516
# 1        Ingreso bajo   207.9927
# 2  Ingreso medio alto   878.3135
# 3  Ingreso medio alto   736.5644
# 4        Ingreso alto   971.8720

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[178], line 2
#       1 #Removiendo una columna
# ----> 2 data.head()
#
# NameError: name 'data' is not defined

# %%
#comparacion contra R
datos['xyz']= [1,2,3,4,5] ##Error sin opción de reutilizar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[164], line 2
#       1 #comparacion contra R
# ----> 2 datos['xyz']= [1,2,3,4,5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
# ...

# %%
#Removiendo una columna
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso  MiCalculo
# 0        Ingreso alto   808.2516
# 1        Ingreso bajo   207.9927
# 2  Ingreso medio alto   878.3135
# 3  Ingreso medio alto   736.5644
# 4        Ingreso alto   971.8720

# %%
datos= datos.drop('MiCalculo',axis=1)

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#Filtrando un dataframe
# FIltrando de aplica a las filas

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
datos.UsuariosInternet < 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: UsuariosInternet, Length: 195, dtype: bool

# %%
filtro = datos.UsuariosInternet < 2

# %%
filtro
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: UsuariosInternet, Length: 195, dtype: bool

# %%
datos[30:40]
# Out:
#        NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 30         Canada        CAN           10.900             85.80
# 31    Switzerland        CHE           10.200             86.34
# 32          Chile        CHL           13.385             66.50
# 33          China        CHN           12.100             45.80
# 34  Cote d'Ivoire        CIV           37.320              8.40
# 35       Cameroon        CMR           37.236              6.40
# 36    Congo, Rep.        COG           37.011              6.60
# 37       Colombia        COL           16.076             51.70
# 38        Comoros        COM           34.326              6.50
# 39     Cabo Verde        CPV           21.625             37.50
#
#           GrupoIngreso
# 30        Ingreso alto
# 31        Ingreso alto
# 32        Ingreso alto
# 33  Ingreso medio alto
# 34  Ingreso medio bajo
# 35  Ingreso medio bajo
# 36  Ingreso medio bajo
# 37  Ingreso medio alto
# 38        Ingreso bajo
# ...

# %%
datos[filtro] #Conceptualmente como R donde el valor de filtro es true
# Out:
#        NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 11        Burundi        BDI           44.151               1.3
# 52        Eritrea        ERI           34.800               0.9
# 55       Ethiopia        ETH           32.925               1.9
# 64         Guinea        GIN           37.337               1.6
# 117       Myanmar        MMR           18.119               1.6
# 127         Niger        NER           49.661               1.7
# 154  Sierra Leone        SLE           36.729               1.7
# 156       Somalia        SOM           43.891               1.5
# 172   Timor-Leste        TLS           35.755               1.1
#
#            GrupoIngreso
# 11         Ingreso bajo
# 52         Ingreso bajo
# 55         Ingreso bajo
# 64         Ingreso bajo
# 117  Ingreso medio bajo
# 127        Ingreso bajo
# 154        Ingreso bajo
# 156        Ingreso bajo
# 172  Ingreso medio bajo

# %%
filtro2 = datos.TasaNatalalidad > 40

# %%
datos[filtro2]
# Out:
#            NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 2              Angola        AGO           45.985              19.1
# 11            Burundi        BDI           44.151               1.3
# 14       Burkina Faso        BFA           40.551               9.1
# 65        Gambia, The        GMB           42.525              14.0
# 115              Mali        MLI           44.138               3.5
# 127             Niger        NER           49.661               1.7
# 128           Nigeria        NGA           40.045              38.0
# 156           Somalia        SOM           43.891               1.5
# 167              Chad        TCD           45.745               2.3
# 178            Uganda        UGA           43.474              16.2
# 192  Congo, Dem. Rep.        COD           42.394               2.2
# 193            Zambia        ZMB           40.471              15.4
#
#            GrupoIngreso
# 2    Ingreso medio alto
# 11         Ingreso bajo
# ...

# %%
#incluso más interesante

# %%
datos[filtro & filtro2]
# Out:
#     NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  GrupoIngreso
# 11     Burundi        BDI           44.151               1.3  Ingreso bajo
# 127      Niger        NER           49.661               1.7  Ingreso bajo
# 156    Somalia        SOM           43.891               1.5  Ingreso bajo

# %%
datos[(datos.TasaNatalalidad > 40) & (datos.UsuariosInternet < 2)]
# Out:
#     NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  GrupoIngreso
# 11     Burundi        BDI           44.151               1.3  Ingreso bajo
# 127      Niger        NER           49.661               1.7  Ingreso bajo
# 156    Somalia        SOM           43.891               1.5  Ingreso bajo

# %%
#Otro ejemplo

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
datos[datos.GrupoIngreso == "Ingreso alto"]
# Out:
#                 NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                    Aruba        ABW           10.244             78.90
# 4     United Arab Emirates        ARE           11.044             88.00
# 5                Argentina        ARG           17.716             59.90
# 7      Antigua and Barbuda        ATG           16.447             63.40
# 8                Australia        AUS           13.200             83.00
# ..                     ...        ...              ...               ...
# 174    Trinidad and Tobago        TTO           14.590             63.80
# 180                Uruguay        URY           14.374             57.69
# 181          United States        USA           12.500             84.20
# 184          Venezuela, RB        VEN           19.842             54.90
# 185  Virgin Islands (U.S.)        VIR           10.700             45.30
#
#      GrupoIngreso
# 0    Ingreso alto
# 4    Ingreso alto
# 5    Ingreso alto
# ...

# %%
datos.GrupoIngreso.unique()
# Out:
# array(['Ingreso alto', 'Ingreso bajo', 'Ingreso medio alto',
#        'Ingreso medio bajo'], dtype=object)

# %%
#Ejercicio Rápido
#Encuentra todo acerca de Malta

# %%
datos[datos.NombrePais == "Malta"]
# Out:
#     NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  GrupoIngreso
# 116      Malta        MLT              9.5           68.9138  Ingreso alto

# %%
#Accesando elementos individuales

# %%
datos[2,2]  #Error Por qué?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 datos[2,2]
#
# ...

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#.at #para etiquetas
#.iat #para ubicación con número enteros

# %%
datos.iat[3,4]
# Out:
# 'Ingreso medio alto'

# %%
datos.iat[0,1]
# Out:
# 'ABW'

# %%
datos.at[2, 'TasaNatalalidad']
# Out:
# 45.985

# %%
#¿Por qué necesitamos .at?

# %%
sub10 = datos[::10]

# %%
sub10
# Out:
#       NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0          Aruba        ABW           10.244         78.900000
# 10    Azerbaijan        AZE           18.300         58.700000
# 20       Belarus        BLR           12.500         54.170000
# 30        Canada        CAN           10.900         85.800000
# 40    Costa Rica        CRI           15.022         45.960000
# 50       Ecuador        ECU           21.070         40.353684
# 60         Gabon        GAB           30.555          9.200000
# 70     Greenland        GRL           14.500         65.800000
# 80         India        IND           20.291         15.100000
# 90    Kazakhstan        KAZ           22.730         54.000000
# 100        Libya        LBY           21.425         16.500000
# 110      Moldova        MDA           12.141         45.000000
# 120   Mozambique        MOZ           39.705          5.400000
# 130  Netherlands        NLD           10.200         93.956400
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10, 'NombrePais']
# Out:
# 'Azerbaijan'

# %%
#Introducción a Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,4
import warnings
warnings.filterwarnings('ignore')

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalalidad  UsuariosInternet  \
# 0                 Aruba        ABW           10.244              78.9
# 1           Afghanistan        AFG           35.253               5.9
# 2                Angola        AGO           45.985              19.1
# 3               Albania        ALB           12.877              57.2
# 4  United Arab Emirates        ARE           11.044              88.0
#
#          GrupoIngreso
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#Distribucion
vis1 = sns.distplot(datos['UsuariosInternet'])

# %%
vis1 = sns.distplot(datos['UsuariosInternet'], bins= 30)

# %%
vis2 = sns.boxplot(data=datos, x = 'GrupoIngreso', y = 'TasaNatalalidad')

# %%
#Galería de Seaborn

# %%
vis3 = sns.lmplot(data = datos, x='UsuariosInternet', y= 'TasaNatalalidad', \
                  fit_reg= False, hue='GrupoIngreso' , aspect=2)

# %%
# Tamaño del marcador

# %%
vis3 = sns.lmplot(data = datos, x='UsuariosInternet', y= 'TasaNatalalidad', \
                  fit_reg= False, hue='GrupoIngreso' , aspect=1, scatter_kws={"s":100} )
