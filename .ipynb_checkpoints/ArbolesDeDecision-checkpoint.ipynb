# %%
import pandas as pd
import numpy as no
import matplotlib as plt
import seaborn as sns

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: E6A3-0F0C
#
#  Directorio de C:\Users\danny
#
# 22/07/2024  10:23    <DIR>          .
# 22/07/2024  10:23    <DIR>          ..
# 15/03/2024  14:52    <DIR>          .afirma
# 03/07/2024  17:00    <DIR>          .anaconda
# 23/01/2024  13:55    <DIR>          .android
# 09/02/2024  16:12               225 .angular-config.json
# 09/03/2024  04:36               223 .bash_history
# 09/02/2024  16:30                99 .bash_profile
# 09/02/2024  16:12                68 .bashrc
# 19/07/2024  14:17    <DIR>          .bito
# 11/11/2023  14:28    <DIR>          .cache
# 22/07/2024  10:25    <DIR>          .conda
# 14/06/2024  15:05                25 .condarc
# 19/02/2024  21:14    <DIR>          .console-ninja
# 14/06/2024  15:05    <DIR>          .continuum
# 18/07/2024  18:21    <DIR>          .cufflinks
# 18/02/2024  14:31    <DIR>          .docker
# 14/11/2023  21:56    <DIR>          .eclipse
# ...
